# %% [markdown]
# ##             <center>HELLO FRESH DATA SCIENCE ASSIGNMENT</center>

# %% [markdown]
# **1\. Import the different libraries to be used for the data exploration and prediction**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt  # Data visualization
import seaborn as sns # Data visualization
import numpy as np   #fundamental package for scientific computing
import pandas as pd  #fundamental package for data analysis
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **2\. Read the train_data csv file and assign it to a dataframe named "df"**

# %%
df = pd.read_csv('data/UKretail.csv', encoding='latin1')

# %% [markdown]
# **3\. Data exploration**

# %%
df.head() #quick look at the first five rows of the dataset
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 3    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 4    536366     22633               HAND WARMER UNION JACK         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:02       7.65     17850.0  United Kingdom
# 1  2010-12-01 08:26:02       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:02       3.39     17850.0  United Kingdom
# 3  2010-12-01 08:26:02       2.55     17850.0  United Kingdom
# 4  2010-12-01 08:28:02       1.85     17850.0  United Kingdom

# %%
df.isnull().sum() # clean dataset with no "nan" values in any columns
# Out:
# InvoiceNo          0
# StockCode          0
# Description      870
# Quantity           0
# InvoiceDate        0
# UnitPrice          0
# CustomerID     80991
# Country            0
# dtype: int64

# %%
df.info() #high overview of the dataset with columns datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325145 entries, 0 to 325144
# Data columns (total 8 columns):
# InvoiceNo      325145 non-null object
# StockCode      325145 non-null object
# Description    324275 non-null object
# Quantity       325145 non-null int64
# InvoiceDate    325145 non-null object
# UnitPrice      325145 non-null float64
# CustomerID     244154 non-null float64
# Country        325145 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 19.8+ MB

# %%
df.describe() #handy statistics about numerical columns
# Out:
#             Quantity      UnitPrice     CustomerID
# count  325145.000000  325145.000000  244154.000000
# mean        9.273340       4.845239   15288.823120
# std       154.394112     116.830451    1713.496816
# min    -80995.000000  -11062.060000   12347.000000
# 25%         1.000000       1.250000   13959.000000
# 50%         3.000000       2.080000   15150.000000
# 75%        10.000000       4.130000   16792.750000
# max     12540.000000   38970.000000   18287.000000

# %%
df['InvoiceDate'].dtype
# Out:
# dtype('O')

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          297350
# Germany                   5745
# France                    5124
# EIRE                      4979
# Spain                     1447
# Netherlands               1398
# Belgium                   1210
# Switzerland               1190
# Portugal                   894
# Australia                  771
# Norway                     664
# Italy                      501
# Channel Islands            453
# Finland                    403
# Cyprus                     376
# Unspecified                271
# Sweden                     265
# Denmark                    235
# Austria                    231
# Japan                      206
# Poland                     198
# USA                        183
# Israel                     170
# Hong Kong                  163
# Singapore                  142
# Iceland                    103
# Canada                      89
# Greece                      87
# Malta                       76
# United Arab Emirates        42
# ...

# %%
len(df['StockCode'].unique())
# Out:
# 3947

# %%
len(df['CustomerID'].unique())
# Out:
# 4325

# %%
len(df['Description'].unique())
# Out:
# 4071

# %%
len(df[df['InvoiceNo'].str.startswith('C')])
# Out:
# 5587

# %%
#Drop rows with no customer ID
df = df.dropna(subset = ['CustomerID'])

# %%
#Convert Customer ID to integers
df['CustomerID'] = df['CustomerID'].astype('int')

# %%
#Convert Invoice Data to a Date Format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']).dt.date

# %%
#Convert date to ordinal values
df['InvoiceDate'] = df['InvoiceDate'].apply(lambda x: x.toordinal())
starting_date = datevalue.min()
latest_date = datevalue.max()
print("earliest date: ",datevalue.min(),"\n","latest date: ",datevalue.max())
# Out:
# earliest date:  734107
#  latest date:  734480

# %%
#Reorder the dataset and order by customer ID, stockCode and Invoice Date
df = df[['CustomerID','StockCode','InvoiceDate', 'InvoiceNo','Description', 'Quantity','UnitPrice','Country']]
df = df.sort_values(['CustomerID', 'StockCode', 'InvoiceDate'],ascending=[1, 1, 1])

# %%
df.head()
# Out:
#         CustomerID StockCode  InvoiceDate InvoiceNo  \
# 88912        12347     16008       734234    549222
# 43297        12347     20719       734163    542237
# 171921       12347     20719       734351    562032
# 321007       12347     20719       734478    581180
# 8944         12347     20780       734113    537626
#
#                                 Description  Quantity  UnitPrice  Country
# 88912   SMALL FOLDING SCISSOR(POINTED EDGE)        24       0.25  Iceland
# 43297                WOODLAND CHARLOTTE BAG        10       0.85  Iceland
# 171921               WOODLAND CHARLOTTE BAG        10       0.85  Iceland
# 321007               WOODLAND CHARLOTTE BAG        10       0.85  Iceland
# 8944              BLACK EAR MUFF HEADPHONES        12       4.65  Iceland

# %% [markdown]
# **4\. Prediction of revenue for next order of each customer**

# %%
final = df.copy()
final['Revenue'] = final['Quantity'] * final['UnitPrice']
final = final[['StockCode', 'CustomerID', 'InvoiceDate', 'Revenue']]

# %%
final2 = final.groupby([final['CustomerID'],final['InvoiceDate']]).sum()

# %%
final2 = final2.reset_index()

# %%
test_customer = final2[final2['CustomerID'] == 12347 ]

# %%
frequency = len(test_customer)

# %%
T = latest_date - test_customer['InvoiceDate'][0]

# %%
recency = test_customer['InvoiceDate'][frequency - 1] - test_customer['InvoiceDate'][0]

# %%
df["CustomerID"].unique()
# Out:
# array([12347, 12348, 12349, ..., 18282, 18283, 18287])

# %%
def create_lifetime_df():
    df2 = pd.DataFrame(index = df["CustomerID"].unique(),columns=['frequency', 'T', 'recency'])
    for i in df["CustomerID"].unique():
        customer_df = final2[final2['CustomerID'] == i ].reset_index()
        frequency = len(customer_df)
        T = latest_date - customer_df['InvoiceDate'][0]
        recency = customer_df['InvoiceDate'][frequency - 1] - customer_df['InvoiceDate'][0]
        df2.loc[i, 'frequency'] = int(frequency)
        df2.loc[i, 'T'] = int(T)
        df2.loc[i, 'recency'] = int(recency)
    return df2

# %%
lifetime_df = create_lifetime_df()

# %%
lifetime_df[lifetime_df.index == 15107]
# Out:
#       frequency    T recency
# 15107         6  372      42

# %%
lifetime_df.shape
# Out:
# (4324, 3)

# %%
lifetime_df['frequency'] = lifetime_df['frequency'].astype(int)
lifetime_df['recency'] = lifetime_df['recency'].astype(int)
lifetime_df['T'] = lifetime_df['T'].astype(int)

# %%
lifetime_df2 = lifetime_df[(lifetime_df['frequency'] > 1)]

# %%
lifetime_df2.shape
# Out:
# (2891, 3)

# %%
lifetime_df3 = lifetime_df2[(lifetime_df2['recency'] > 60) | (lifetime_df2['T'] < 180)]

# %%
lifetime_df3.shape
# Out:
# (2730, 3)

# %%
lifetime_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2730 entries, 12347 to 18287
# Data columns (total 3 columns):
# frequency    2730 non-null int64
# T            2730 non-null int64
# recency      2730 non-null int64
# dtypes: int64(3)
# memory usage: 85.3 KB

# %%
import lifetimes
from lifetimes import BetaGeoFitter

# %% [markdown]
#  Customers buy stochastically according to a Poisson distribution with purchasing rate λ.  After each purchase the customer has p% chance of becoming inactive.  Therefore, the time period at which a customer becomes inactive is distributed as a shifted geometric distribution.  The customer-base is heterogeneous across those two parameters such that we can assume a gamma and beta distribution respectively.  Lastly we assume that λ and p across customers are jointly independent.  This makes some of the math later on much easier.

# %% [markdown]
# 1. Frequency: The number of repeat purchases that they have made.
# 2. Recency: When was the last time that they have made a purchase since their first purchase.
# 3. Customer Age: The end of our observation period minus out the period that they made their first purchase.

# %%
from lifetimes import BetaGeoFitter

# similar API to scikit-learn and lifelines.
bgf = BetaGeoFitter(penalizer_coef=0.0)
bgf.fit(lifetime_df3['frequency'], lifetime_df3['recency'], lifetime_df3['T'])
print(bgf)
"""
<lifetimes.BetaGeoFitter: fitted with 2357 subjects, a: 0.79, alpha: 4.41, b: 2.43, r: 0.24>
"""
# Out:
# <lifetimes.BetaGeoFitter: fitted with 2730 subjects, a: 0.00, alpha: 81.84, b: 0.00, r: 2.06>
# '\n<lifetimes.BetaGeoFitter: fitted with 2357 subjects, a: 0.79, alpha: 4.41, b: 2.43, r: 0.24>\n'

# %%
from lifetimes.plotting import plot_frequency_recency_matrix

plot_frequency_recency_matrix(bgf)

# %%
from lifetimes.plotting import plot_probability_alive_matrix

plot_probability_alive_matrix(bgf)

# %%
#t = 1
#lifetime_df['predicted_purchases'] = bgf.conditional_expected_number_of_purchases_up_to_time(t, lifetime_df['frequency'], lifetime_df['recency'], lifetime_df['T'])
#lifetime_df.sort_values(by='predicted_purchases')

# %%
def f(x):
    if x > 1:
        x = 0
    return x

# %%
#cumulative probabilities
for i in range(1,700):
    t = i 
    lifetime_df3['predicted_purchases_cum_'+ str(i)] = bgf.conditional_expected_number_of_purchases_up_to_time(t, lifetime_df3['frequency'], lifetime_df3['recency'], lifetime_df3['T'])
#     if lifetime_df['predicted_purchases_cum_'+ str(i)] > 1:
#         lifetime_df['predicted_purchases_cum_'+ str(i)] = 0
    lifetime_df3['predicted_purchases_cum_'+ str(i)] = lifetime_df3['predicted_purchases_cum_'+ str(i)].apply(lambda x : f(x))

# %%
def f2(x):
    if x < 0:
        x = 0
    return x

# %%
#calculate probabilities
for i in range(2,700):
    t = i
    lifetime_df3['predicted_purchases_'+ str(i)] = lifetime_df3['predicted_purchases_cum_'+ str(i)] - lifetime_df3['predicted_purchases_cum_'+ str(i - 1)]
    lifetime_df3['predicted_purchases_'+ str(i)] = lifetime_df3['predicted_purchases_'+ str(i)].apply(lambda x : f2(x))

# %%
lifetime_df3 = lifetime_df3[lifetime_df3.columns.drop(list(lifetime_df3.filter(regex='predicted_purchases_cum_')))]

# %%
lifetime_df3
# Out:
#        frequency    T  recency  predicted_purchases_2  predicted_purchases_3  \
# 12347          7  367      365               0.020178               0.020178
# 12348          4  358      283               0.013771               0.013771
# 12352          7  296      260               0.023970               0.023970
# 12356          3  325      303               0.012430               0.012430
# 12358          2  150      149               0.017499               0.017499
# 12359          6  331      324               0.019516               0.019516
# 12360          3  200      148               0.017942               0.017942
# 12362         13  295      292               0.039955               0.039955
# 12363          2  242      133               0.012528               0.012528
# 12364          4  112      105               0.031247               0.031247
# 12370          4  360      309               0.013708               0.013708
# ...

# %%
prob = lifetime_df3.iloc[:,3:].sum(axis=1)

# %%
prob
# Out:
# 12347    0.968564
# 12348    0.977719
# 12352    0.958804
# 12356    0.981948
# 12358    0.979925
# 12359    0.975787
# 12360    0.968890
# 12362    0.958930
# 12363    0.977146
# 12364    0.968643
# 12370    0.973294
# 12372    0.977012
# 12375    0.956032
# 12379    0.963827
# 12380    0.976036
# 12381    0.948686
# 12383    0.975967
# 12384    0.972281
# 12388    0.967995
# 12393    0.980602
# 12394    0.977436
# 12395    0.957367
# 12397    0.972874
# 12399    0.971674
# 12406    0.973799
# 12407    0.979442
# 12408    0.966333
# 12409    0.964177
# 12412    0.967669
# 12413    0.983357
#            ...
# 18228    0.943204
# 18229    0.921376
# 18230    0.965038
# 18231    0.958529
# 18232    0.961701
# 18235    0.981461
# 18236    0.951282
# 18237    0.948147
# 18239    0.974251
# 18241    0.906340
# 18242    0.977624
# 18245    0.969265
# 18246    0.979307
# 18248    0.972391
# 18252    0.978763
# 18257    0.958201
# 18259    0.982385
# 18260    0.960323
# 18261    0.963517
# ...

# %%
prob.argmin()
# Out:
# 17841

# %%
lifetime_df3[lifetime_df3.index == 17841]
# Out:
#        frequency    T  recency  predicted_purchases_2  predicted_purchases_3  \
# 17841        113  373      372               0.252959               0.252959
#
#        predicted_purchases_4  predicted_purchases_5  predicted_purchases_6  \
# 17841                    0.0                    0.0                    0.0
#
#        predicted_purchases_7  predicted_purchases_8           ...             \
# 17841                    0.0                    0.0           ...
#
#        predicted_purchases_690  predicted_purchases_691  \
# 17841                        0                        0
#
#        predicted_purchases_692  predicted_purchases_693  \
# 17841                        0                        0
#
#        predicted_purchases_694  predicted_purchases_695  \
# 17841                        0                        0
#
#        predicted_purchases_696  predicted_purchases_697  \
# 17841                        0                        0
#
# ...

# %%
t = 3
lifetime_df3 = lifetime_df3[lifetime_df3.index == 17841]
bgf.conditional_expected_number_of_purchases_up_to_time(t, lifetime_df3['frequency'], lifetime_df3['recency'], lifetime_df3['T'])
# Out:
# 17841    0.758878
# dtype: float64

# %%
df[df.CustomerID == 15107]
# Out:
#        CustomerID StockCode  InvoiceDate InvoiceNo  \
# 18303       15107     20914       734120    538869
# 33991       15107     21781       734150    541109
# 29944       15107     22168       734146    540542
# 31446       15107     22168       734148   C540796
# 33992       15107     22168       734150    541109
# 2421        15107     22191       734108    536748
# 19421       15107     22191       734121   C539063
# 2422        15107    72760B       734108    536748
# 2423        15107     84945       734108    536748
# 18304       15107    84968A       734120    538869
# 29945       15107    85123A       734146    540542
#
#                                Description  Quantity  UnitPrice  \
# 18303  SET/5 RED RETROSPOT LID GLASS BOWLS         6       2.95
# 33991              MA CAMPAGNE CUTLERY BOX         1      14.95
# 29944        ORGANISER WOOD ANTIQUE WHITE          2       8.50
# 31446        ORGANISER WOOD ANTIQUE WHITE         -1       8.50
# ...

# %%
from lifetimes.plotting import plot_period_transactions
plot_period_transactions(bgf)

# %%
t = 10 #predict purchases in 10 periods
individual = lifetime_df.iloc[0]
# The below function is an alias to `bfg.conditional_expected_number_of_purchases_up_to_time`
bgf.predict(t, individual['frequency'], individual['recency'], individual['T'])
# 0.0576511
# Out:
# 0.20902985651068831
